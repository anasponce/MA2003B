# %%
import pandas as pd

df = pd.read_excel('../data_para_limpiar/sureste.xlsx')

# %%
from PREPHelper import *

# %%
df['date'] = pd.to_datetime(df['date'])
df = df.set_index('date')

full_index = pd.date_range(start=df.index.min(), end=df.index.max(), freq='H')

df = df.reindex(full_index)

print(df.isna().sum())

# %%
cols = ['PM10', 'NO2', 'CO', 'SO2', 'O3', 'PM2.5']
data = fill_all_gaps_arima(df, cols)

# %%
data_overview(data)
# Out:
# Dataset shape: (22630, 17)
#
# Data Types and Null Values:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22630 entries, 0 to 22629
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    22630 non-null  datetime64[ns]
#  1   CO      22350 non-null  float64
#  2   NO      21886 non-null  float64
#  3   NO2     22098 non-null  float64
#  4   NOX     22094 non-null  float64
#  5   O3      21988 non-null  float64
#  6   PM10    22062 non-null  float64
#  7   PM2.5   18482 non-null  float64
#  8   PRS     22406 non-null  float64
#  9   RAINF   22406 non-null  float64
#  10  RH      22343 non-null  float64
#  11  SO2     21681 non-null  float64
#  12  SR      22556 non-null  float64
#  13  TOUT    22411 non-null  float64
#  14  WDR     8665 non-null   float64
#  15  WDV     13740 non-null  float64
#  16  WSR     22410 non-null  float64
# dtypes: datetime64[ns](1), float64(16)
# memory usage: 2.9 MB
# None
#
# Data Summary (Descriptive Statistics):
#                                 date            CO            NO  \
# count                          22630  22350.000000  21886.000000
# mean   2023-04-17 11:21:33.963764736      1.456403     10.472380
# min              2022-01-01 00:00:00      0.050000      0.900000
# 25%              2022-08-24 17:15:00      0.830000      3.100000
# 50%              2023-04-17 11:30:00      1.380000      4.300000
# 75%              2023-12-09 05:45:00      1.930000      9.500000
# max              2024-07-31 23:00:00     37.000000    210.000000
# std                              NaN      0.778640     15.724676
#
#                 NO2           NOX            O3          PM10         PM2.5  \
# count  22098.000000  22094.000000  21988.000000  22062.000000  18482.000000
# mean      13.577926     23.930339     28.220302     51.303205     16.500519
# min        1.100000      2.900000      2.000000      2.000000      2.000000
# 25%        6.300000      9.800000     15.000000     28.000000      9.280000
# 50%       10.700000     15.300000     25.000000     44.000000     14.200000
# 75%       18.200000     29.400000     38.000000     66.000000     21.190000
# max       77.400000    239.400000    163.000000    800.000000    177.680000
# std        9.737118     22.569450     18.077479     35.924153     10.052941
#
#                 PRS         RAINF            RH           SO2            SR  \
# count  22406.000000  22406.000000  22343.000000  21681.000000  22556.000000
# mean     722.321503      0.097610     58.612675      3.776763      0.125839
# min      682.900000      0.000000      1.000000      0.500000      0.000000
# 25%      719.800000      0.000000     42.000000      2.500000      0.000000
# 50%      722.100000      0.000000     60.000000      3.300000      0.007000
# 75%      724.700000      0.000000     76.000000      4.400000      0.223000
# max      737.500000     17.990000     97.000000     42.800000      0.672000
# std        4.095119      1.258082     21.101805      2.184159      0.181364
#
#                TOUT          WDR           WDV           WSR
# count  22411.000000  8665.000000  13740.000000  22410.000000
# mean      23.573791   136.356607    138.196652     10.545382
# min       -3.030000     1.000000      1.000000      0.300000
# 25%       18.530000    88.000000     88.000000      6.000000
# 50%       24.370000   107.000000    109.000000      9.800000
# 75%       28.820000   153.000000    167.250000     14.700000
# max       43.620000   360.000000    360.000000     31.200000
# std        7.505879    82.951007     84.166747      5.449306
#
# Missing Values:
# date         0
# CO         280
# NO         744
# NO2        532
# NOX        536
# O3         642
# PM10       568
# PM2.5     4148
# PRS        224
# RAINF      224
# RH         287
# SO2        949
# SR          74
# TOUT       219
# WDR      13965
# WDV       8890
# WSR        220
# dtype: int64
#
# First 5 rows:
#                  date    CO    NO   NO2   NOX   O3   PM10   PM2.5    PRS  \
# 0 2022-01-01 00:00:00  2.36  19.8  48.4  68.0  5.0  142.0  111.00  715.7
# 1 2022-01-01 01:00:00  2.29  10.8  44.5  55.1  6.0  168.0  112.16  715.5
# 2 2022-01-01 02:00:00  2.71  28.3  47.1  75.2  4.0  203.0  139.31  715.4
# 3 2022-01-01 03:00:00  2.31  19.6  42.1  61.5  5.0  262.0  177.68  715.1
# 4 2022-01-01 04:00:00  1.85  13.0  39.5  52.5  4.0  185.0  134.21  715.1
#
#    RAINF    RH  SO2   SR   TOUT    WDR  WDV  WSR
# 0    0.0  59.0  4.0  0.0  21.65  285.0  NaN  6.5
# 1    0.0  59.0  4.6  0.0  21.21  284.0  NaN  7.1
# 2    0.0  62.0  5.9  0.0  21.21  290.0  NaN  7.7
# 3    0.0  59.0  5.5  0.0  20.44  294.0  NaN  8.2
# 4    0.0  59.0  4.9  0.0  19.80  287.0  NaN  8.1

# %% [markdown]
# ## se usarán las variables PM10, NO2, CO, SO2, O3 y PM2.5

# %%
describe_variables(data)
# Out:
# Description of variables:
#
# Column: PM10
# Description: Air quality pollutant concentration in µg/m³ (for PM10, PM2.5) or µg/m³ (for other gases).
# Data Type: float64
# Possible values: Numeric, may include values of zero or negative numbers.
# Missing values: 568 missing entries.
# --------------------------------------------------
# Column: NO2
# Description: Air quality pollutant concentration in µg/m³ (for PM10, PM2.5) or µg/m³ (for other gases).
# Data Type: float64
# Possible values: Numeric, may include values of zero or negative numbers.
# Missing values: 532 missing entries.
# --------------------------------------------------
# Column: CO
# Description: Air quality pollutant concentration in µg/m³ (for PM10, PM2.5) or µg/m³ (for other gases).
# Data Type: float64
# Possible values: Numeric, may include values of zero or negative numbers.
# Missing values: 280 missing entries.
# --------------------------------------------------
# Column: SO2
# Description: Air quality pollutant concentration in µg/m³ (for PM10, PM2.5) or µg/m³ (for other gases).
# Data Type: float64
# Possible values: Numeric, may include values of zero or negative numbers.
# Missing values: 949 missing entries.
# --------------------------------------------------
# Column: O3
# Description: Air quality pollutant concentration in µg/m³ (for PM10, PM2.5) or µg/m³ (for other gases).
# Data Type: float64
# Possible values: Numeric, may include values of zero or negative numbers.
# Missing values: 642 missing entries.
# --------------------------------------------------
# Column: PM2.5
# Description: Air quality pollutant concentration in µg/m³ (for PM10, PM2.5) or µg/m³ (for other gases).
# Data Type: float64
# Possible values: Numeric, may include values of zero or negative numbers.
# Missing values: 4148 missing entries.
# --------------------------------------------------

# %%
explore_quantitative_variables(data)
# Out:
# Measures of Central Tendency:
# PM10 - Mean: 51.30, Median: 44.00, Mode: 40.00
# NO2 - Mean: 13.58, Median: 10.70, Mode: 6.80
# CO - Mean: 1.46, Median: 1.38, Mode: 0.76
# SO2 - Mean: 3.78, Median: 3.30, Mode: 2.40
# O3 - Mean: 28.22, Median: 25.00, Mode: 5.00
# PM2.5 - Mean: 16.50, Median: 14.20, Mode: 15.00
#
# Measures of Dispersion:
# PM10 - Range: 798.00, Variance: 1290.54, Std Dev: 35.92
# NO2 - Range: 76.30, Variance: 94.81, Std Dev: 9.74
# CO - Range: 36.95, Variance: 0.61, Std Dev: 0.78
# SO2 - Range: 42.30, Variance: 4.77, Std Dev: 2.18
# O3 - Range: 161.00, Variance: 326.80, Std Dev: 18.08
# PM2.5 - Range: 175.68, Variance: 101.06, Std Dev: 10.05

# %%
visualize_outliers(data)
# Out:
# PM10 - Outliers: 768 outliers
# NO2 - Outliers: 756 outliers
# CO - Outliers: 50 outliers
# SO2 - Outliers: 1042 outliers
# O3 - Outliers: 511 outliers
# PM2.5 - Outliers: 591 outliers

# %%
plot_histograms(data)

# %%
plot_correlation_heatmap(data)
