# %%
import pandas as pd

df = pd.read_excel('../data_para_limpiar/sureste.xlsx')

# %%
from PREPHelper import *

# %%
df['date'] = pd.to_datetime(df['date'])
df = df.set_index('date')

full_index = pd.date_range(start=df.index.min(), end=df.index.max(), freq='H')

df = df.reindex(full_index)

print(df.isna().sum())
# Out:
# CO         282
# NO         746
# NO2        534
# NOX        538
# O3         644
# PM10       570
# PM2.5     4150
# PRS        226
# RAINF      226
# RH         289
# SO2        951
# SR          76
# TOUT       221
# WDR      13967
# WDV       8892
# WSR        222
# dtype: int64
# /var/folders/l9/hx3k3fcs03d6gz71m2n3t1c80000gn/T/ipykernel_10022/3299174593.py:4: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   full_index = pd.date_range(start=df.index.min(), end=df.index.max(), freq='H')

# %%
cols = ['PM10', 'NO2', 'CO', 'SO2', 'O3', 'PM2.5']
data = fill_all_gaps_arima(df, cols)
# Out:
# /Users/marielalvarez/2025/5to_sem/multivariados/quintosem/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# /Users/marielalvarez/2025/5to_sem/multivariados/quintosem/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# /Users/marielalvarez/2025/5to_sem/multivariados/quintosem/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# /Users/marielalvarez/2025/5to_sem/multivariados/quintosem/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /Users/marielalvarez/2025/5to_sem/multivariados/quintosem/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /Users/marielalvarez/2025/5to_sem/multivariados/quintosem/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# /Users/marielalvarez/2025/5to_sem/multivariados/quintosem/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# /Users/marielalvarez/2025/5to_sem/multivariados/quintosem/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# /Users/marielalvarez/2025/5to_sem/multivariados/quintosem/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /Users/marielalvarez/2025/5to_sem/multivariados/quintosem/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /Users/marielalvarez/2025/5to_sem/multivariados/quintosem/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# /Users/marielalvarez/2025/5to_sem/multivariados/quintosem/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# /Users/marielalvarez/2025/5to_sem/multivariados/quintosem/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# /Users/marielalvarez/2025/5to_sem/multivariados/quintosem/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /Users/marielalvarez/2025/5to_sem/multivariados/quintosem/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /Users/marielalvarez/2025/5to_sem/multivariados/quintosem/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# /Users/marielalvarez/2025/5to_sem/multivariados/quintosem/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# /Users/marielalvarez/2025/5to_sem/multivariados/quintosem/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# /Users/marielalvarez/2025/5to_sem/multivariados/quintosem/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /Users/marielalvarez/2025/5to_sem/multivariados/quintosem/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /Users/marielalvarez/2025/5to_sem/multivariados/quintosem/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# /Users/marielalvarez/2025/5to_sem/multivariados/quintosem/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# /Users/marielalvarez/2025/5to_sem/multivariados/quintosem/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# /Users/marielalvarez/2025/5to_sem/multivariados/quintosem/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /Users/marielalvarez/2025/5to_sem/multivariados/quintosem/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /Users/marielalvarez/2025/5to_sem/multivariados/quintosem/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# /Users/marielalvarez/2025/5to_sem/multivariados/quintosem/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# /Users/marielalvarez/2025/5to_sem/multivariados/quintosem/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# /Users/marielalvarez/2025/5to_sem/multivariados/quintosem/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /Users/marielalvarez/2025/5to_sem/multivariados/quintosem/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %%
data_overview(data)
# Out:
# Dataset shape: (22632, 16)
#
# Data Types and Null Values:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 22632 entries, 2022-01-01 00:00:00 to 2024-07-31 23:00:00
# Freq: h
# Data columns (total 16 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   CO      22632 non-null  float64
#  1   NO      21886 non-null  float64
#  2   NO2     22632 non-null  float64
#  3   NOX     22094 non-null  float64
#  4   O3      22632 non-null  float64
#  5   PM10    22632 non-null  float64
#  6   PM2.5   22632 non-null  float64
#  7   PRS     22406 non-null  float64
#  8   RAINF   22406 non-null  float64
#  9   RH      22343 non-null  float64
#  10  SO2     22632 non-null  float64
#  11  SR      22556 non-null  float64
#  12  TOUT    22411 non-null  float64
#  13  WDR     8665 non-null   float64
#  14  WDV     13740 non-null  float64
#  15  WSR     22410 non-null  float64
# dtypes: float64(16)
# memory usage: 2.9 MB
# None
#
# Data Summary (Descriptive Statistics):
#                  CO            NO           NO2           NOX            O3  \
# count  22632.000000  21886.000000  22632.000000  22094.000000  22632.000000
# mean       1.455508     10.472380     13.566478     23.930339     28.103738
# std        0.779811     15.724676      9.781660     22.569450     18.052578
# min        0.050000      0.900000      1.100000      2.900000     -0.997795
# 25%        0.830000      3.100000      6.300000      9.800000     15.000000
# 50%        1.380000      4.300000     10.700000     15.300000     25.000000
# 75%        1.930000      9.500000     18.200000     29.400000     38.000000
# max       37.000000    210.000000     77.400000    239.400000    163.000000
#
#                PM10         PM2.5           PRS         RAINF            RH  \
# count  22632.000000  22632.000000  22406.000000  22406.000000  22343.000000
# mean      51.159443     16.362768    722.321503      0.097610     58.612675
# std       35.645038      9.694629      4.095119      1.258082     21.101805
# min        2.000000      1.885088    682.900000      0.000000      1.000000
# 25%       28.000000      9.620000    719.800000      0.000000     42.000000
# 50%       44.000000     15.000000    722.100000      0.000000     60.000000
# 75%       66.000000     20.390000    724.700000      0.000000     76.000000
# max      800.000000    177.680000    737.500000     17.990000     97.000000
#
#                 SO2            SR          TOUT          WDR           WDV  \
# count  22632.000000  22556.000000  22411.000000  8665.000000  13740.000000
# mean       3.785271      0.125839     23.573791   136.356607    138.196652
# std        2.175606      0.181364      7.505879    82.951007     84.166747
# min        0.500000      0.000000     -3.030000     1.000000      1.000000
# 25%        2.500000      0.000000     18.530000    88.000000     88.000000
# 50%        3.300000      0.007000     24.370000   107.000000    109.000000
# 75%        4.400000      0.223000     28.820000   153.000000    167.250000
# max       42.800000      0.672000     43.620000   360.000000    360.000000
#
#                 WSR
# count  22410.000000
# mean      10.545382
# std        5.449306
# min        0.300000
# 25%        6.000000
# 50%        9.800000
# 75%       14.700000
# max       31.200000
#
# Missing Values:
# CO           0
# NO         746
# NO2          0
# NOX        538
# O3           0
# PM10         0
# PM2.5        0
# PRS        226
# RAINF      226
# RH         289
# SO2          0
# SR          76
# TOUT       221
# WDR      13967
# WDV       8892
# WSR        222
# dtype: int64
#
# First 5 rows:
#                        CO    NO   NO2   NOX   O3   PM10   PM2.5    PRS  RAINF  \
# 2022-01-01 00:00:00  2.36  19.8  48.4  68.0  5.0  142.0  111.00  715.7    0.0
# 2022-01-01 01:00:00  2.29  10.8  44.5  55.1  6.0  168.0  112.16  715.5    0.0
# 2022-01-01 02:00:00  2.71  28.3  47.1  75.2  4.0  203.0  139.31  715.4    0.0
# 2022-01-01 03:00:00  2.31  19.6  42.1  61.5  5.0  262.0  177.68  715.1    0.0
# 2022-01-01 04:00:00  1.85  13.0  39.5  52.5  4.0  185.0  134.21  715.1    0.0
#
#                        RH  SO2   SR   TOUT    WDR  WDV  WSR
# 2022-01-01 00:00:00  59.0  4.0  0.0  21.65  285.0  NaN  6.5
# 2022-01-01 01:00:00  59.0  4.6  0.0  21.21  284.0  NaN  7.1
# 2022-01-01 02:00:00  62.0  5.9  0.0  21.21  290.0  NaN  7.7
# 2022-01-01 03:00:00  59.0  5.5  0.0  20.44  294.0  NaN  8.2
# 2022-01-01 04:00:00  59.0  4.9  0.0  19.80  287.0  NaN  8.1

# %% [markdown]
# ## se usarán las variables PM10, NO2, CO, SO2, O3 y PM2.5

# %%
describe_variables(data)
# Out:
# Description of variables:
#
# Column: PM10
# Description: Air quality pollutant concentration in µg/m³ (for PM10, PM2.5) or µg/m³ (for other gases).
# Data Type: float64
# Possible values: Numeric, may include values of zero or negative numbers.
# Missing values: 0 missing entries.
# --------------------------------------------------
# Column: NO2
# Description: Air quality pollutant concentration in µg/m³ (for PM10, PM2.5) or µg/m³ (for other gases).
# Data Type: float64
# Possible values: Numeric, may include values of zero or negative numbers.
# Missing values: 0 missing entries.
# --------------------------------------------------
# Column: CO
# Description: Air quality pollutant concentration in µg/m³ (for PM10, PM2.5) or µg/m³ (for other gases).
# Data Type: float64
# Possible values: Numeric, may include values of zero or negative numbers.
# Missing values: 0 missing entries.
# --------------------------------------------------
# Column: SO2
# Description: Air quality pollutant concentration in µg/m³ (for PM10, PM2.5) or µg/m³ (for other gases).
# Data Type: float64
# Possible values: Numeric, may include values of zero or negative numbers.
# Missing values: 0 missing entries.
# --------------------------------------------------
# Column: O3
# Description: Air quality pollutant concentration in µg/m³ (for PM10, PM2.5) or µg/m³ (for other gases).
# Data Type: float64
# Possible values: Numeric, may include values of zero or negative numbers.
# Missing values: 0 missing entries.
# --------------------------------------------------
# Column: PM2.5
# Description: Air quality pollutant concentration in µg/m³ (for PM10, PM2.5) or µg/m³ (for other gases).
# Data Type: float64
# Possible values: Numeric, may include values of zero or negative numbers.
# Missing values: 0 missing entries.
# --------------------------------------------------

# %%
explore_quantitative_variables(data)
# Out:
# Measures of Central Tendency:
# PM10 - Mean: 51.16, Median: 44.00, Mode: 40.00
# NO2 - Mean: 13.57, Median: 10.70, Mode: 6.80
# CO - Mean: 1.46, Median: 1.38, Mode: 0.76
# SO2 - Mean: 3.79, Median: 3.30, Mode: 2.40
# O3 - Mean: 28.10, Median: 25.00, Mode: 5.00
# PM2.5 - Mean: 16.36, Median: 15.00, Mode: 15.40
#
# Measures of Dispersion:
# PM10 - Range: 798.00, Variance: 1270.57, Std Dev: 35.65
# NO2 - Range: 76.30, Variance: 95.68, Std Dev: 9.78
# CO - Range: 36.95, Variance: 0.61, Std Dev: 0.78
# SO2 - Range: 42.30, Variance: 4.73, Std Dev: 2.18
# O3 - Range: 164.00, Variance: 325.90, Std Dev: 18.05
# PM2.5 - Range: 175.79, Variance: 93.99, Std Dev: 9.69

# %%
visualize_outliers(data)
# Out:
# PM10 - Outliers: 770 outliers
# NO2 - Outliers: 783 outliers
# CO - Outliers: 51 outliers
# SO2 - Outliers: 1084 outliers
# O3 - Outliers: 522 outliers
# PM2.5 - Outliers: 930 outliers

# %%
plot_histograms(data)

# %%
plot_correlation_heatmap(data)
