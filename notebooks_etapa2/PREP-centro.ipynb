# %%
import pandas as pd

df = pd.read_excel('../data_para_limpiar/centro.xlsx')

# %%
import PREPHelper
import importlib
importlib.reload(PREPHelper)
# Out:
# <module 'PREPHelper' from 'c:\\Users\\ipaso\\OneDrive\\Documents\\GitHub\\MA2003B\\notebooks_etapa2\\PREPHelper.py'>

# %%
from PREPHelper import *

# %%
df['date'] = pd.to_datetime(df['date'])
df = df.set_index('date')

full_index = pd.date_range(start=df.index.min(), end=df.index.max(), freq='H')

df = df.reindex(full_index)

print(df.isna().sum())
# Out:
# CO         477
# NO        1272
# NO2        490
# NOX        489
# O3         870
# PM10       542
# PM2.5     3415
# PRS        452
# RAINF      419
# RH         565
# SO2       1350
# SR         177
# TOUT       417
# WDR      14030
# WDV       9040
# WSR        422
# dtype: int64
# C:\Users\ipaso\AppData\Local\Temp\ipykernel_23484\3299174593.py:4: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   full_index = pd.date_range(start=df.index.min(), end=df.index.max(), freq='H')

# %%
cols = ['PM10', 'NO2', 'CO', 'SO2', 'O3', 'PM2.5']
data = impute_with_random_forest(df, cols)

# %%
data_overview(data)
# Out:
# Dataset shape: (22632, 16)
#
# Data Types and Null Values:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 22632 entries, 2022-01-01 00:00:00 to 2024-07-31 23:00:00
# Freq: h
# Data columns (total 16 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   CO      22632 non-null  float64
#  1   NO      21360 non-null  float64
#  2   NO2     22632 non-null  float64
#  3   NOX     22143 non-null  float64
#  4   O3      22632 non-null  float64
#  5   PM10    22632 non-null  float64
#  6   PM2.5   22632 non-null  float64
#  7   PRS     22180 non-null  float64
#  8   RAINF   22213 non-null  float64
#  9   RH      22067 non-null  float64
#  10  SO2     22632 non-null  float64
#  11  SR      22455 non-null  float64
#  12  TOUT    22215 non-null  float64
#  13  WDR     8602 non-null   float64
#  14  WDV     13592 non-null  float64
#  15  WSR     22210 non-null  float64
# dtypes: float64(16)
# memory usage: 3.4 MB
# None
#
# Data Summary (Descriptive Statistics):
#                  CO            NO           NO2           NOX            O3  \
# count  22632.000000  21360.000000  22632.000000  22143.000000  22632.000000
# mean       1.651717      8.983240     16.642214     25.748214     28.280566
# std        0.784069     13.543627     11.289636     21.698165     19.793118
# min        0.070000      0.500000      0.400000      1.400000      1.000000
# 25%        1.060000      2.600000      7.800000     11.200000     13.000000
# 50%        1.540000      3.700000     14.000000     19.000000     24.000000
# 75%        2.190000      9.400000     22.500000     32.500000     39.000000
# max        5.630000    288.400000     92.200000    362.800000    164.000000
#
#                PM10         PM2.5           PRS         RAINF            RH  \
# count  22632.000000  22632.000000  22180.000000  22213.000000  22067.000000
# mean      63.617780     24.638314    711.245298      0.001035     53.508406
# std       35.261556     14.553897      3.660924      0.023644     20.506207
# min        3.000000      2.000000    682.400000      0.000000      1.000000
# 25%       40.000000     14.040000    708.900000      0.000000     37.000000
# 50%       56.000000     21.531592    711.000000      0.000000     55.000000
# 75%       78.000000     31.622500    713.300000      0.000000     70.000000
# max      791.000000    152.000000    724.900000      1.200000     93.000000
#
#                 SO2            SR          TOUT          WDR           WDV  \
# count  22632.000000  22455.000000  22215.000000  8602.000000  13592.000000
# mean       4.623932      0.186991     22.893814   102.822367    105.466157
# std        2.558755      0.283482      7.349970    87.278237     89.669793
# min        0.500000      0.000000     -2.940000     1.000000      1.000000
# 25%        2.900000      0.001000     17.895000    47.000000     47.000000
# 50%        4.000000      0.007000     23.740000    72.000000     72.000000
# 75%        5.600000      0.304000     28.040000   118.000000    119.000000
# max       73.900000      1.216000     42.340000   360.000000    360.000000
#
#                 WSR
# count  22210.000000
# mean       7.893643
# std        3.920236
# min        0.100000
# 25%        4.800000
# 50%        7.600000
# 75%       10.500000
# max       24.800000
#
# Missing Values:
# CO           0
# NO        1272
# NO2          0
# NOX        489
# O3           0
# PM10         0
# PM2.5        0
# PRS        452
# RAINF      419
# RH         565
# SO2          0
# SR         177
# TOUT       417
# WDR      14030
# WDV       9040
# WSR        422
# dtype: int64
#
# First 5 rows:
#                        CO   NO     NO2   NOX    O3   PM10   PM2.5    PRS  \
# 2022-01-01 00:00:00  2.60  3.5  44.900  48.5  15.0  134.0   91.00  705.5
# 2022-01-01 01:00:00  2.23  2.9  32.900  36.0  19.0  141.0  112.61  705.2
# 2022-01-01 02:00:00  1.99  2.9  27.600  30.7  21.0  117.0   92.46  705.1
# 2022-01-01 03:00:00  2.03  NaN   4.885   NaN  18.0  108.0   69.20  704.8
# 2022-01-01 04:00:00  1.86  NaN   4.882   NaN  20.0  106.0   68.03  704.8
#
#                      RAINF    RH  SO2   SR   TOUT    WDR  WDV  WSR
# 2022-01-01 00:00:00    0.0  46.0  5.3  0.0  21.37  267.0  NaN  3.4
# 2022-01-01 01:00:00    0.0  48.0  6.1  0.0  20.83  259.0  NaN  3.3
# 2022-01-01 02:00:00    0.0  46.0  5.8  0.0  20.52  233.0  NaN  5.9
# 2022-01-01 03:00:00    0.0  46.0  6.0  0.0  20.12  220.0  NaN  5.1
# 2022-01-01 04:00:00    0.0  46.0  5.6  0.0  19.85  244.0  NaN  4.7

# %% [markdown]
# ## se usarán las variables PM10, NO2, CO, SO2, O3 y PM2.5

# %%
describe_variables(data)
# Out:
# Description of variables:
#
# Column: PM10
# Description: Air quality pollutant concentration in µg/m³ (for PM10, PM2.5) or µg/m³ (for other gases).
# Data Type: float64
# Possible values: Numeric, may include values of zero or negative numbers.
# Missing values: 0 missing entries.
# --------------------------------------------------
# Column: NO2
# Description: Air quality pollutant concentration in µg/m³ (for PM10, PM2.5) or µg/m³ (for other gases).
# Data Type: float64
# Possible values: Numeric, may include values of zero or negative numbers.
# Missing values: 0 missing entries.
# --------------------------------------------------
# Column: CO
# Description: Air quality pollutant concentration in µg/m³ (for PM10, PM2.5) or µg/m³ (for other gases).
# Data Type: float64
# Possible values: Numeric, may include values of zero or negative numbers.
# Missing values: 0 missing entries.
# --------------------------------------------------
# Column: SO2
# Description: Air quality pollutant concentration in µg/m³ (for PM10, PM2.5) or µg/m³ (for other gases).
# Data Type: float64
# Possible values: Numeric, may include values of zero or negative numbers.
# Missing values: 0 missing entries.
# --------------------------------------------------
# Column: O3
# Description: Air quality pollutant concentration in µg/m³ (for PM10, PM2.5) or µg/m³ (for other gases).
# Data Type: float64
# Possible values: Numeric, may include values of zero or negative numbers.
# Missing values: 0 missing entries.
# --------------------------------------------------
# Column: PM2.5
# Description: Air quality pollutant concentration in µg/m³ (for PM10, PM2.5) or µg/m³ (for other gases).
# Data Type: float64
# Possible values: Numeric, may include values of zero or negative numbers.
# Missing values: 0 missing entries.
# --------------------------------------------------

# %%
explore_quantitative_variables(data)
# Out:
# Measures of Central Tendency:
# PM10 - Mean: 63.62, Median: 56.00, Mode: 46.00
# NO2 - Mean: 16.64, Median: 14.00, Mode: 4.89
# CO - Mean: 1.65, Median: 1.54, Mode: 2.66
# SO2 - Mean: 4.62, Median: 4.00, Mode: 2.30
# O3 - Mean: 28.28, Median: 24.00, Mode: 10.00
# PM2.5 - Mean: 24.64, Median: 21.53, Mode: 11.00
#
# Measures of Dispersion:
# PM10 - Range: 788.00, Variance: 1243.38, Std Dev: 35.26
# NO2 - Range: 91.80, Variance: 127.46, Std Dev: 11.29
# CO - Range: 5.56, Variance: 0.61, Std Dev: 0.78
# SO2 - Range: 73.40, Variance: 6.55, Std Dev: 2.56
# O3 - Range: 163.00, Variance: 391.77, Std Dev: 19.79
# PM2.5 - Range: 150.00, Variance: 211.82, Std Dev: 14.55

# %%
visualize_outliers(data)
# Out:
# PM10 - Outliers: 786 outliers
# NO2 - Outliers: 560 outliers
# CO - Outliers: 67 outliers
# SO2 - Outliers: 911 outliers
# O3 - Outliers: 509 outliers
# PM2.5 - Outliers: 662 outliers

# %%
plot_histograms(data)

# %%
plot_correlation_heatmap(data)

# %%
data.to_excel('../data_preparada/centro_prep.xlsx')
