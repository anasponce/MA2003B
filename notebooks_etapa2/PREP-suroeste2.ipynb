# %%
import pandas as pd

df = pd.read_excel('../data_para_limpiar/suroeste2.xlsx')

# %%
import PREPHelper
import importlib
importlib.reload(PREPHelper)
# Out:
# <module 'PREPHelper' from 'c:\\Users\\ipaso\\OneDrive\\Documents\\GitHub\\MA2003B\\notebooks_etapa2\\PREPHelper.py'>

# %%
from PREPHelper import *

# %%
df['date'] = pd.to_datetime(df['date'])
df = df.set_index('date')

full_index = pd.date_range(start=df.index.min(), end=df.index.max(), freq='H')

df = df.reindex(full_index)

print(df.isna().sum())
# Out:
# CO        356
# NO        538
# NO2       276
# NOX       279
# O3        477
# PM10      924
# PM2.5    1659
# PRS       208
# RAINF     201
# RH        394
# SO2       384
# SR         41
# TOUT      202
# WDR       697
# WSR       201
# dtype: int64
# C:\Users\ipaso\AppData\Local\Temp\ipykernel_19740\3299174593.py:4: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   full_index = pd.date_range(start=df.index.min(), end=df.index.max(), freq='H')

# %%
cols = ['PM10', 'NO2', 'CO', 'SO2', 'O3', 'PM2.5']
data = impute_with_random_forest(df, cols)

# %%
data_overview(data)
# Out:
# Dataset shape: (22632, 15)
#
# Data Types and Null Values:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 22632 entries, 2022-01-01 00:00:00 to 2024-07-31 23:00:00
# Freq: h
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   CO      22632 non-null  float64
#  1   NO      22094 non-null  float64
#  2   NO2     22632 non-null  float64
#  3   NOX     22353 non-null  float64
#  4   O3      22632 non-null  float64
#  5   PM10    22632 non-null  float64
#  6   PM2.5   22632 non-null  float64
#  7   PRS     22424 non-null  float64
#  8   RAINF   22431 non-null  float64
#  9   RH      22238 non-null  float64
#  10  SO2     22632 non-null  float64
#  11  SR      22591 non-null  float64
#  12  TOUT    22430 non-null  float64
#  13  WDR     21935 non-null  float64
#  14  WSR     22431 non-null  float64
# dtypes: float64(15)
# memory usage: 3.3 MB
# None
#
# Data Summary (Descriptive Statistics):
# ...

# %% [markdown]
# ## se usarán las variables PM10, NO2, CO, SO2, O3 y PM2.5

# %%
describe_variables(data)
# Out:
# Description of variables:
#
# Column: PM10
# Description: Air quality pollutant concentration in µg/m³ (for PM10, PM2.5) or µg/m³ (for other gases).
# Data Type: float64
# Possible values: Numeric, may include values of zero or negative numbers.
# Missing values: 0 missing entries.
# --------------------------------------------------
# Column: NO2
# Description: Air quality pollutant concentration in µg/m³ (for PM10, PM2.5) or µg/m³ (for other gases).
# Data Type: float64
# Possible values: Numeric, may include values of zero or negative numbers.
# Missing values: 0 missing entries.
# --------------------------------------------------
# Column: CO
# Description: Air quality pollutant concentration in µg/m³ (for PM10, PM2.5) or µg/m³ (for other gases).
# Data Type: float64
# Possible values: Numeric, may include values of zero or negative numbers.
# Missing values: 0 missing entries.
# --------------------------------------------------
# Column: SO2
# ...

# %%
explore_quantitative_variables(data)
# Out:
# Measures of Central Tendency:
# PM10 - Mean: 64.72, Median: 57.00, Mode: 50.00
# NO2 - Mean: 16.67, Median: 14.90, Mode: 4.91
# CO - Mean: 1.49, Median: 1.33, Mode: 1.06
# SO2 - Mean: 4.44, Median: 3.90, Mode: 3.60
# O3 - Mean: 27.81, Median: 23.00, Mode: 6.00
# PM2.5 - Mean: 18.10, Median: 15.00, Mode: 11.00
#
# Measures of Dispersion:
# PM10 - Range: 997.00, Variance: 1788.58, Std Dev: 42.29
# NO2 - Range: 96.70, Variance: 100.93, Std Dev: 10.05
# CO - Range: 6.81, Variance: 0.80, Std Dev: 0.90
# SO2 - Range: 83.30, Variance: 5.52, Std Dev: 2.35
# O3 - Range: 175.00, Variance: 436.59, Std Dev: 20.89
# PM2.5 - Range: 104.00, Variance: 144.76, Std Dev: 12.03

# %%
visualize_outliers(data)
# Out:
# PM10 - Outliers: 755 outliers
# NO2 - Outliers: 593 outliers
# CO - Outliers: 560 outliers
# SO2 - Outliers: 1561 outliers
# O3 - Outliers: 672 outliers
# PM2.5 - Outliers: 666 outliers

# %%
plot_histograms(data)

# %%
plot_correlation_heatmap(data)

# %%
data.to_excel('../data_preparada/suroeste2_prep.xlsx')
