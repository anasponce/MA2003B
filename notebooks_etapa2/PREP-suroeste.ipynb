# %%
import pandas as pd

df = pd.read_excel('../data_para_limpiar/suroeste.xlsx')

# %%
from PREPHelper import *

# %%
df['date'] = pd.to_datetime(df['date'])
df = df.set_index('date')

full_index = pd.date_range(start=df.index.min(), end=df.index.max(), freq='H')

df = df.reindex(full_index)

print(df.isna().sum())
# Out:
# CO        1314
# NO         776
# NO2        753
# NOX        753
# O3        1254
# PM10       646
# PM2.5     2737
# PRS        919
# RAINF      531
# RH         541
# SO2        813
# SR         408
# TOUT       527
# WDR      14110
# WDV       9054
# WSR        619
# dtype: int64
# /var/folders/l9/hx3k3fcs03d6gz71m2n3t1c80000gn/T/ipykernel_10166/3299174593.py:4: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   full_index = pd.date_range(start=df.index.min(), end=df.index.max(), freq='H')

# %%
cols = ['PM10', 'NO2', 'CO', 'SO2', 'O3', 'PM2.5']
data = fill_all_gaps_arima(df, cols)

# %%
data_overview(data)
# Out:
# Dataset shape: (22632, 16)
#
# Data Types and Null Values:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 22632 entries, 2022-01-01 00:00:00 to 2024-07-31 23:00:00
# Freq: h
# Data columns (total 16 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   CO      22632 non-null  float64
#  1   NO      21856 non-null  float64
#  2   NO2     22632 non-null  float64
#  3   NOX     21879 non-null  float64
#  4   O3      22632 non-null  float64
#  5   PM10    22632 non-null  float64
#  6   PM2.5   22632 non-null  float64
#  7   PRS     21713 non-null  float64
#  8   RAINF   22101 non-null  float64
#  9   RH      22091 non-null  float64
#  10  SO2     22632 non-null  float64
#  11  SR      22224 non-null  float64
#  12  TOUT    22105 non-null  float64
#  13  WDR     8522 non-null   float64
#  14  WDV     13578 non-null  float64
#  15  WSR     22013 non-null  float64
# dtypes: float64(16)
# memory usage: 2.9 MB
# None
#
# Data Summary (Descriptive Statistics):
#                  CO            NO           NO2           NOX            O3  \
# count  22632.000000  21856.000000  22632.000000  21879.000000  22632.000000
# mean       1.662756     15.010803     18.342965     33.183651     28.074816
# std        0.848086     27.896877     11.286204     35.785223     21.138802
# min        0.000000      0.800000      0.000000      0.600000     -8.726550
# 25%        0.860000      3.400000     10.000000     13.500000     12.000000
# 50%        1.680000      5.300000     15.599032     21.300000     23.120444
# 75%        2.360600     12.300000     24.000000     37.000000     39.000000
# max        6.520000    362.700000     92.500000    412.700000    175.776272
#
#                PM10         PM2.5           PRS         RAINF            RH  \
# count  22632.000000  22632.000000  21713.000000  22101.000000  22091.000000
# mean      66.141141     25.687723    700.927113      0.005012     53.884795
# std       48.137360     18.655893      4.392322      0.219232     20.734258
# min        0.000000      0.000000    680.000000      0.000000      1.000000
# 25%       36.000000     13.680000    698.600000      0.000000     38.000000
# 50%       54.000000     21.670000    701.000000      0.000000     55.000000
# 75%       80.000000     33.070349    703.400000      0.000000     70.500000
# max      802.000000    570.770752    715.500000     17.990000    100.000000
#
#                 SO2            SR          TOUT          WDR           WDV  \
# count  22632.000000  22224.000000  22105.000000  8522.000000  13578.000000
# mean       6.177937      0.181288     22.781845   140.808144    145.184269
# std        3.199453      0.390797      7.370729    75.991903     80.556176
# min        0.000000     -0.004000     -2.600000     1.000000      1.000000
# 25%        4.600000      0.000000     17.720000    97.000000     97.000000
# 50%        5.500000      0.000000     23.710000   114.000000    114.000000
# 75%        7.000000      0.298000     28.030000   146.000000    150.000000
# max      177.800000      7.786000     43.420000   360.000000    360.000000
#
#                 WSR
# count  22013.000000
# mean       8.518598
# std        4.704079
# min        0.100000
# 25%        4.500000
# 50%        8.000000
# 75%       12.100000
# max       30.400000
#
# Missing Values:
# CO           0
# NO         776
# NO2          0
# NOX        753
# O3           0
# PM10         0
# PM2.5        0
# PRS        919
# RAINF      531
# RH         541
# SO2          0
# SR         408
# TOUT       527
# WDR      14110
# WDV       9054
# WSR        619
# dtype: int64
#
# First 5 rows:
#                        CO    NO   NO2   NOX   O3   PM10  PM2.5    PRS  RAINF  \
# 2022-01-01 00:00:00  0.00   NaN   0.0   NaN  0.0    0.0    0.0    NaN    NaN
# 2022-01-01 01:00:00  3.28  29.1  46.5  75.6  5.0  232.0  225.0  694.9    0.0
# 2022-01-01 02:00:00  3.25  38.7  42.0  80.7  5.0  234.0  181.0  694.9    0.0
# 2022-01-01 03:00:00  3.02  39.1  40.4  79.5  4.0  183.0  140.0  694.6    0.0
# 2022-01-01 04:00:00  2.73  37.2  39.0  76.2  3.0  137.0   91.0  694.4    0.0
#
#                        RH  SO2   SR   TOUT    WDR  WDV  WSR
# 2022-01-01 00:00:00   NaN  0.0  NaN    NaN    NaN  NaN  NaN
# 2022-01-01 01:00:00  57.0  5.4  0.0  19.11  287.0  NaN  3.4
# 2022-01-01 02:00:00  57.0  5.3  0.0  18.50  333.0  NaN  1.4
# 2022-01-01 03:00:00  58.0  5.4  0.0  18.19  273.0  NaN  3.3
# 2022-01-01 04:00:00  55.0  5.9  0.0  18.78  315.0  NaN  1.6

# %% [markdown]
# ## se usarán las variables PM10, NO2, CO, SO2, O3 y PM2.5

# %%
describe_variables(data)
# Out:
# Description of variables:
#
# Column: PM10
# Description: Air quality pollutant concentration in µg/m³ (for PM10, PM2.5) or µg/m³ (for other gases).
# Data Type: float64
# Possible values: Numeric, may include values of zero or negative numbers.
# Missing values: 0 missing entries.
# --------------------------------------------------
# Column: NO2
# Description: Air quality pollutant concentration in µg/m³ (for PM10, PM2.5) or µg/m³ (for other gases).
# Data Type: float64
# Possible values: Numeric, may include values of zero or negative numbers.
# Missing values: 0 missing entries.
# --------------------------------------------------
# Column: CO
# Description: Air quality pollutant concentration in µg/m³ (for PM10, PM2.5) or µg/m³ (for other gases).
# Data Type: float64
# Possible values: Numeric, may include values of zero or negative numbers.
# Missing values: 0 missing entries.
# --------------------------------------------------
# Column: SO2
# Description: Air quality pollutant concentration in µg/m³ (for PM10, PM2.5) or µg/m³ (for other gases).
# Data Type: float64
# Possible values: Numeric, may include values of zero or negative numbers.
# Missing values: 0 missing entries.
# --------------------------------------------------
# Column: O3
# Description: Air quality pollutant concentration in µg/m³ (for PM10, PM2.5) or µg/m³ (for other gases).
# Data Type: float64
# Possible values: Numeric, may include values of zero or negative numbers.
# Missing values: 0 missing entries.
# --------------------------------------------------
# Column: PM2.5
# Description: Air quality pollutant concentration in µg/m³ (for PM10, PM2.5) or µg/m³ (for other gases).
# Data Type: float64
# Possible values: Numeric, may include values of zero or negative numbers.
# Missing values: 0 missing entries.
# --------------------------------------------------

# %%
explore_quantitative_variables(data)
# Out:
# Measures of Central Tendency:
# PM10 - Mean: 66.14, Median: 54.00, Mode: 31.00
# NO2 - Mean: 18.34, Median: 15.60, Mode: 7.60
# CO - Mean: 1.66, Median: 1.68, Mode: 0.54
# SO2 - Mean: 6.18, Median: 5.50, Mode: 5.30
# O3 - Mean: 28.07, Median: 23.12, Mode: 8.00
# PM2.5 - Mean: 25.69, Median: 21.67, Mode: 33.07
#
# Measures of Dispersion:
# PM10 - Range: 802.00, Variance: 2317.21, Std Dev: 48.14
# NO2 - Range: 92.50, Variance: 127.38, Std Dev: 11.29
# CO - Range: 6.52, Variance: 0.72, Std Dev: 0.85
# SO2 - Range: 177.80, Variance: 10.24, Std Dev: 3.20
# O3 - Range: 184.50, Variance: 446.85, Std Dev: 21.14
# PM2.5 - Range: 570.77, Variance: 348.04, Std Dev: 18.66

# %%
visualize_outliers(data)
# Out:
# PM10 - Outliers: 1272 outliers
# NO2 - Outliers: 657 outliers
# CO - Outliers: 45 outliers
# SO2 - Outliers: 1543 outliers
# O3 - Outliers: 622 outliers
# PM2.5 - Outliers: 805 outliers

# %%
plot_histograms(data)

# %%
plot_correlation_heatmap(data)
