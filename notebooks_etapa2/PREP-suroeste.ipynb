# %%
import pandas as pd

data = pd.read_excel('../data_para_limpiar/suroeste.xlsx')

# %%
from PREPHelper import *

# %%
data_overview(data)
# Out:
# Dataset shape: (22630, 17)
#
# Data Types and Null Values:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22630 entries, 0 to 22629
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    22630 non-null  datetime64[ns]
#  1   CO      21318 non-null  float64
#  2   NO      21856 non-null  float64
#  3   NO2     21879 non-null  float64
#  4   NOX     21879 non-null  float64
#  5   O3      21378 non-null  float64
#  6   PM10    21986 non-null  float64
#  7   PM2.5   19895 non-null  float64
#  8   PRS     21713 non-null  float64
#  9   RAINF   22101 non-null  float64
#  10  RH      22091 non-null  float64
#  11  SO2     21819 non-null  float64
#  12  SR      22224 non-null  float64
#  13  TOUT    22105 non-null  float64
#  14  WDR     8522 non-null   float64
#  15  WDV     13578 non-null  float64
#  16  WSR     22013 non-null  float64
# dtypes: datetime64[ns](1), float64(16)
# memory usage: 2.9 MB
# None
#
# Data Summary (Descriptive Statistics):
#                                 date            CO            NO  \
# count                          22630  21318.000000  21856.000000
# mean   2023-04-17 11:21:33.963764736      1.673922     15.010803
# min              2022-01-01 00:00:00      0.050000      0.800000
# 25%              2022-08-24 17:15:00      0.850000      3.400000
# 50%              2023-04-17 11:30:00      1.710000      5.300000
# 75%              2023-12-09 05:45:00      2.380000     12.300000
# max              2024-07-31 23:00:00      6.520000    362.700000
# std                              NaN      0.853786     27.896877
#
#                 NO2           NOX            O3          PM10         PM2.5  \
# count  21879.000000  21879.000000  21378.000000  21986.000000  19895.000000
# mean      18.340020     33.183651     28.008747     65.987146     25.413261
# min        0.200000      0.600000      1.000000      3.000000      2.000000
# 25%        9.900000     13.500000     12.000000     36.000000     13.530000
# 50%       15.500000     21.300000     23.000000     53.000000     21.000000
# 75%       24.000000     37.000000     38.000000     80.000000     32.000000
# max       92.500000    412.700000    164.000000    802.000000    556.000000
# std       11.298432     35.785223     20.928219     48.361327     18.099253
#
#                 PRS         RAINF            RH           SO2            SR  \
# count  21713.000000  22101.000000  22091.000000  21819.000000  22224.000000
# mean     700.927113      0.005012     53.884795      6.156662      0.181288
# min      680.000000      0.000000      1.000000      0.500000     -0.004000
# 25%      698.600000      0.000000     38.000000      4.600000      0.000000
# 50%      701.000000      0.000000     55.000000      5.500000      0.000000
# 75%      703.400000      0.000000     70.500000      7.000000      0.298000
# max      715.500000     17.990000    100.000000    177.800000      7.786000
# std        4.392322      0.219232     20.734258      3.215236      0.390797
#
#                TOUT          WDR           WDV           WSR
# count  22105.000000  8522.000000  13578.000000  22013.000000
# mean      22.781845   140.808144    145.184269      8.518598
# min       -2.600000     1.000000      1.000000      0.100000
# 25%       17.720000    97.000000     97.000000      4.500000
# 50%       23.710000   114.000000    114.000000      8.000000
# 75%       28.030000   146.000000    150.000000     12.100000
# max       43.420000   360.000000    360.000000     30.400000
# std        7.370729    75.991903     80.556176      4.704079
#
# Missing Values:
# date         0
# CO        1312
# NO         774
# NO2        751
# NOX        751
# O3        1252
# PM10       644
# PM2.5     2735
# PRS        917
# RAINF      529
# RH         539
# SO2        811
# SR         406
# TOUT       525
# WDR      14108
# WDV       9052
# WSR        617
# dtype: int64
#
# First 5 rows:
#                  date    CO    NO   NO2   NOX   O3   PM10  PM2.5    PRS  \
# 0 2022-01-01 00:00:00   NaN   NaN   NaN   NaN  NaN    NaN    NaN    NaN
# 1 2022-01-01 01:00:00  3.28  29.1  46.5  75.6  5.0  232.0  225.0  694.9
# 2 2022-01-01 02:00:00  3.25  38.7  42.0  80.7  5.0  234.0  181.0  694.9
# 3 2022-01-01 03:00:00  3.02  39.1  40.4  79.5  4.0  183.0  140.0  694.6
# 4 2022-01-01 04:00:00  2.73  37.2  39.0  76.2  3.0  137.0   91.0  694.4
#
#    RAINF    RH  SO2   SR   TOUT    WDR  WDV  WSR
# 0    NaN   NaN  NaN  NaN    NaN    NaN  NaN  NaN
# 1    0.0  57.0  5.4  0.0  19.11  287.0  NaN  3.4
# 2    0.0  57.0  5.3  0.0  18.50  333.0  NaN  1.4
# 3    0.0  58.0  5.4  0.0  18.19  273.0  NaN  3.3
# 4    0.0  55.0  5.9  0.0  18.78  315.0  NaN  1.6

# %% [markdown]
# ## se usarán las variables PM10, NO2, CO, SO2, O3 y PM2.5

# %%
describe_variables(data)
# Out:
# Description of variables:
#
# Column: PM10
# Description: Air quality pollutant concentration in µg/m³ (for PM10, PM2.5) or µg/m³ (for other gases).
# Data Type: float64
# Possible values: Numeric, may include values of zero or negative numbers.
# Missing values: 644 missing entries.
# --------------------------------------------------
# Column: NO2
# Description: Air quality pollutant concentration in µg/m³ (for PM10, PM2.5) or µg/m³ (for other gases).
# Data Type: float64
# Possible values: Numeric, may include values of zero or negative numbers.
# Missing values: 751 missing entries.
# --------------------------------------------------
# Column: CO
# Description: Air quality pollutant concentration in µg/m³ (for PM10, PM2.5) or µg/m³ (for other gases).
# Data Type: float64
# Possible values: Numeric, may include values of zero or negative numbers.
# Missing values: 1312 missing entries.
# --------------------------------------------------
# Column: SO2
# Description: Air quality pollutant concentration in µg/m³ (for PM10, PM2.5) or µg/m³ (for other gases).
# Data Type: float64
# Possible values: Numeric, may include values of zero or negative numbers.
# Missing values: 811 missing entries.
# --------------------------------------------------
# Column: O3
# Description: Air quality pollutant concentration in µg/m³ (for PM10, PM2.5) or µg/m³ (for other gases).
# Data Type: float64
# Possible values: Numeric, may include values of zero or negative numbers.
# Missing values: 1252 missing entries.
# --------------------------------------------------
# Column: PM2.5
# Description: Air quality pollutant concentration in µg/m³ (for PM10, PM2.5) or µg/m³ (for other gases).
# Data Type: float64
# Possible values: Numeric, may include values of zero or negative numbers.
# Missing values: 2735 missing entries.
# --------------------------------------------------

# %%
explore_quantitative_variables(data)
# Out:
# Measures of Central Tendency:
# PM10 - Mean: 65.99, Median: 53.00, Mode: 31.00
# NO2 - Mean: 18.34, Median: 15.50, Mode: 7.60
# CO - Mean: 1.67, Median: 1.71, Mode: 0.54
# SO2 - Mean: 6.16, Median: 5.50, Mode: 5.30
# O3 - Mean: 28.01, Median: 23.00, Mode: 8.00
# PM2.5 - Mean: 25.41, Median: 21.00, Mode: 17.00
#
# Measures of Dispersion:
# PM10 - Range: 799.00, Variance: 2338.82, Std Dev: 48.36
# NO2 - Range: 92.30, Variance: 127.65, Std Dev: 11.30
# CO - Range: 6.47, Variance: 0.73, Std Dev: 0.85
# SO2 - Range: 177.30, Variance: 10.34, Std Dev: 3.22
# O3 - Range: 163.00, Variance: 437.99, Std Dev: 20.93
# PM2.5 - Range: 554.00, Variance: 327.58, Std Dev: 18.10

# %%
visualize_outliers(data)
# Out:
# PM10 - Outliers: 1244 outliers
# NO2 - Outliers: 625 outliers
# CO - Outliers: 39 outliers
# SO2 - Outliers: 1488 outliers
# O3 - Outliers: 628 outliers
# PM2.5 - Outliers: 864 outliers

# %%
plot_histograms(data)

# %%
plot_correlation_heatmap(data)
