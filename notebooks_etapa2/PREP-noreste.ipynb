# %%
import pandas as pd

data = pd.read_excel('../data_para_limpiar/noreste2.xlsx')

# %%
from PREPHelper import *

# %%
data_overview(data)
# Out:
# Dataset shape: (22630, 17)
#
# Data Types and Null Values:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22630 entries, 0 to 22629
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    22630 non-null  datetime64[ns]
#  1   CO      20485 non-null  float64
#  2   NO      22029 non-null  float64
#  3   NO2     22016 non-null  float64
#  4   NOX     22056 non-null  float64
#  5   O3      21179 non-null  float64
#  6   PM10    21819 non-null  float64
#  7   PM2.5   20246 non-null  float64
#  8   PRS     22009 non-null  float64
#  9   RAINF   22135 non-null  float64
#  10  RH      21482 non-null  float64
#  11  SO2     21587 non-null  float64
#  12  SR      22434 non-null  float64
#  13  TOUT    22109 non-null  float64
#  14  WDR     6249 non-null   float64
#  15  WDV     13435 non-null  float64
#  16  WSR     22037 non-null  float64
# dtypes: datetime64[ns](1), float64(16)
# memory usage: 2.9 MB
# None
#
# ...

# %% [markdown]
# ## se usarán las variables PM10, NO2, CO, SO2, O3 y PM2.5

# %%
describe_variables(data)
# Out:
# Description of variables:
#
# Column: PM10
# Description: Air quality pollutant concentration in µg/m³ (for PM10, PM2.5) or µg/m³ (for other gases).
# Data Type: float64
# Possible values: Numeric, may include values of zero or negative numbers.
# Missing values: 811 missing entries.
# --------------------------------------------------
# Column: NO2
# Description: Air quality pollutant concentration in µg/m³ (for PM10, PM2.5) or µg/m³ (for other gases).
# Data Type: float64
# Possible values: Numeric, may include values of zero or negative numbers.
# Missing values: 614 missing entries.
# --------------------------------------------------
# Column: CO
# Description: Air quality pollutant concentration in µg/m³ (for PM10, PM2.5) or µg/m³ (for other gases).
# Data Type: float64
# Possible values: Numeric, may include values of zero or negative numbers.
# Missing values: 2145 missing entries.
# --------------------------------------------------
# Column: SO2
# ...

# %%
explore_quantitative_variables(data)
# Out:
# Measures of Central Tendency:
# PM10 - Mean: 73.75, Median: 65.00, Mode: 50.00
# NO2 - Mean: 17.83, Median: 15.50, Mode: 11.30
# CO - Mean: 2.00, Median: 1.84, Mode: 1.70
# SO2 - Mean: 4.56, Median: 3.50, Mode: 2.50
# O3 - Mean: 22.36, Median: 19.00, Mode: 11.00
# PM2.5 - Mean: 22.60, Median: 19.00, Mode: 13.00
#
# Measures of Dispersion:
# PM10 - Range: 796.00, Variance: 2005.32, Std Dev: 44.78
# NO2 - Range: 100.80, Variance: 115.90, Std Dev: 10.77
# CO - Range: 13.38, Variance: 0.82, Std Dev: 0.90
# SO2 - Range: 76.10, Variance: 13.85, Std Dev: 3.72
# O3 - Range: 129.00, Variance: 210.34, Std Dev: 14.50
# PM2.5 - Range: 349.00, Variance: 255.83, Std Dev: 15.99

# %%
visualize_outliers(data)
# Out:
# PM10 - Outliers: 1131 outliers
# NO2 - Outliers: 585 outliers
# CO - Outliers: 980 outliers
# SO2 - Outliers: 1887 outliers
# O3 - Outliers: 547 outliers
# PM2.5 - Outliers: 519 outliers

# %%
plot_histograms(data)

# %%
plot_correlation_heatmap(data)
