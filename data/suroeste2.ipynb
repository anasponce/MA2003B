# %% [markdown]
# - Nombre: Suroeste 2 San Pedro
# - Clave Estacion: SO2
# - Ubicacion:

# %%
import pandas as pd
from concat_helper import concat_by_station
station_name = "SUROESTE2"   
file_2022_2023 = "DATOS HISTÓRICOS 2022_2023_TODAS ESTACIONES.xlsx"
file_2023_2024 = "DATOS HISTÓRICOS 2023_2024_TODAS ESTACIONES_ITESM.xlsx"

df_final = concat_by_station(file_2022_2023, file_2023_2024, station_name)


assert not (df_final["date"].dt.year == 1970).any(), "Quedó alguna fecha mal parseada."
assert df_final.columns.is_unique, "Hay columnas duplicadas."

print(df_final.head())
print(df_final.tail())
print(df_final["date"].min(), "→", df_final["date"].max())
# Out:
#                  date    CO   NO   NO2   NOX    O3   PM10  PM2.5    PRS  \
# 0 2022-01-01 00:00:00  1.62  2.5  21.6  24.1  33.0  106.0   53.0  711.4
# 1 2022-01-01 01:00:00  1.33  2.5  12.9  15.5  36.0   89.0   49.0  711.3
# 2 2022-01-01 02:00:00  1.29  2.6  14.9  17.5  34.0   77.0   39.0  711.3
# 3 2022-01-01 03:00:00  1.40  2.8  21.2  24.0  25.0   54.0   35.0  711.1
# 4 2022-01-01 04:00:00  1.39  2.8  19.8  22.6  22.0   68.0   35.0  711.1
#
#    RAINF    RH  SO2   SR   TOUT    WDR  WSR
# 0    0.0  43.0  4.8  0.0  20.77  215.0  4.4
# 1    0.0  46.0  4.4  0.0  19.70  202.0  4.8
# 2    0.0  43.0  4.1  0.0  19.37  233.0  5.8
# 3    0.0  45.0  4.7  0.0  19.26  236.0  6.0
# 4    0.0  44.0  4.3  0.0  19.12  150.0  4.8
#                      date    CO   NO  NO2   NOX    O3  PM10  PM2.5    PRS  \
# 22625 2024-07-31 19:00:00  0.50  3.7  5.9   9.6  22.0  85.0   16.0  713.8
# 22626 2024-07-31 20:00:00  0.48  5.1  7.4  12.5  20.0  82.0   19.0  714.0
# 22627 2024-07-31 21:00:00  0.46  3.3  6.4   9.8  21.0  74.0   24.0  714.2
# 22628 2024-07-31 22:00:00   NaN  NaN  NaN   NaN   NaN   NaN    NaN    NaN
# 22629 2024-07-31 23:00:00   NaN  NaN  NaN   NaN   NaN   NaN    NaN    NaN
#
#        RAINF    RH  SO2   SR   TOUT    WDR   WSR
# 22625    0.0  53.0  2.4  0.0  28.34  194.0  12.8
# 22626    0.0  52.0  2.3  0.0  27.95  180.0  14.5
# 22627    0.0  53.0  2.3  0.0  27.38  188.0  14.1
# 22628    NaN   NaN  NaN  NaN    NaN    NaN   NaN
# 22629    NaN   NaN  NaN  NaN    NaN    NaN   NaN
# 2022-01-01 00:00:00 → 2024-07-31 23:00:00

# %%
rango_completo = pd.date_range(start=df_final['date'].min(),
                               end=df_final['date'].max(),
                               freq='H')

horas_faltantes = rango_completo.difference(df_final['date'])

print("Cantidad de horas faltantes:", len(horas_faltantes))
print("Ejemplos de horas faltantes:\n", horas_faltantes[:10])
# Out:
# Cantidad de horas faltantes: 2
# Ejemplos de horas faltantes:
#  DatetimeIndex(['2023-02-11 19:00:00', '2023-10-31 17:00:00'], dtype='datetime64[ns]', freq=None)
# C:\Users\ipaso\AppData\Local\Temp\ipykernel_23624\1722369520.py:1: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   rango_completo = pd.date_range(start=df_final['date'].min(),

# %%
df_final.to_excel("../data_limpia/suroeste2.xlsx", index=False, engine='openpyxl')
