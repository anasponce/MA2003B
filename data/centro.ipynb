# %% [markdown]
# - Nombre: Centro Obispado
# - Clave Estacion: CE Obispado
# - Ubicacion:

# %%
import pandas as pd
from concat_helper import concat_by_station
station_name = "CENTRO"   
file_2022_2023 = "DATOS HISTÓRICOS 2022_2023_TODAS ESTACIONES.xlsx"
file_2023_2024 = "DATOS HISTÓRICOS 2023_2024_TODAS ESTACIONES_ITESM.xlsx"

df_final = concat_by_station(file_2022_2023, file_2023_2024, station_name)


assert not (df_final["date"].dt.year == 1970).any(), "Quedó alguna fecha mal parseada."
assert df_final.columns.is_unique, "Hay columnas duplicadas."

print(df_final.head())
print(df_final.tail())
print(df_final["date"].min(), "→", df_final["date"].max())
# Out:
#                  date    CO   NO   NO2   NOX    O3   PM10   PM2.5    PRS  \
# 0 2022-01-01 00:00:00  2.60  3.5  44.9  48.5  15.0  134.0   91.00  705.5
# 1 2022-01-01 01:00:00  2.23  2.9  32.9  36.0  19.0  141.0  112.61  705.2
# 2 2022-01-01 02:00:00  1.99  2.9  27.6  30.7  21.0  117.0   92.46  705.1
# 3 2022-01-01 03:00:00  2.03  NaN   NaN   NaN  18.0  108.0   69.20  704.8
# 4 2022-01-01 04:00:00  1.86  NaN   NaN   NaN  20.0  106.0   68.03  704.8
#
#    RAINF    RH  SO2   SR   TOUT    WDR  WDV  WSR
# 0    0.0  46.0  5.3  0.0  21.37  267.0  NaN  3.4
# 1    0.0  48.0  6.1  0.0  20.83  259.0  NaN  3.3
# 2    0.0  46.0  5.8  0.0  20.52  233.0  NaN  5.9
# 3    0.0  46.0  6.0  0.0  20.12  220.0  NaN  5.1
# 4    0.0  46.0  5.6  0.0  19.85  244.0  NaN  4.7
#                      date    CO   NO  NO2  NOX    O3  PM10  PM2.5    PRS  \
# 22625 2024-07-31 19:00:00  0.60  2.5  6.4  9.2  28.0  77.0  32.42  710.7
# 22626 2024-07-31 20:00:00  0.57  2.3  6.7  9.2  23.0  89.0  31.45  710.8
# 22627 2024-07-31 21:00:00  0.59  1.9  6.0  8.2  23.0  90.0  31.75  711.2
# 22628 2024-07-31 22:00:00  0.57  1.9  5.9  8.0  22.0  85.0  33.73  711.7
# 22629 2024-07-31 23:00:00  0.55  NaN  4.8  6.9  22.0  85.0  34.73  712.3
#
#        RAINF    RH  SO2     SR   TOUT  WDR    WDV   WSR
# 22625    0.0  47.0  2.7  0.075  30.87  NaN  111.0  16.0
# 22626    0.0  49.0  2.7  0.010  29.39  NaN  131.0  16.3
# 22627    0.0  50.0  2.7  0.001  28.62  NaN  127.0  15.9
# 22628    0.0  50.0  2.7  0.001  28.00  NaN  118.0  11.5
# 22629    0.0  54.0  2.7  0.001  27.15  NaN  128.0  10.5
# 2022-01-01 00:00:00 → 2024-07-31 23:00:00
# c:\Users\ipaso\OneDrive\Documents\GitHub\MA2003B\data\concat_helper.py:64: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   out = pd.concat([df22, df23], ignore_index=True)

# %%
rango_completo = pd.date_range(start=df_final['date'].min(),
                               end=df_final['date'].max(),
                               freq='H')

horas_faltantes = rango_completo.difference(df_final['date'])

print("Cantidad de horas faltantes:", len(horas_faltantes))
print("Ejemplos de horas faltantes:\n", horas_faltantes[:10])
# Out:
# Cantidad de horas faltantes: 2
# Ejemplos de horas faltantes:
#  DatetimeIndex(['2023-02-11 19:00:00', '2023-10-31 17:00:00'], dtype='datetime64[ns]', freq=None)
# C:\Users\ipaso\AppData\Local\Temp\ipykernel_22960\1722369520.py:1: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   rango_completo = pd.date_range(start=df_final['date'].min(),

# %%
df_final.to_excel("../data_limpia/centro.xlsx", index=False, engine='openpyxl')
