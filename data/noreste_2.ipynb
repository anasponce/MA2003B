# %% [markdown]
# - Nombre: Noreste 2
# - Clave Estacion: Apodaca
# - Ubicacion: 25.77722,-100.188055

# %%
import pandas as pd
from concat_helper import concat_by_station
station_name = "NORESTE2"   
file_2022_2023 = "DATOS HISTÓRICOS 2022_2023_TODAS ESTACIONES.xlsx"
file_2023_2024 = "DATOS HISTÓRICOS 2023_2024_TODAS ESTACIONES_ITESM.xlsx"

df_final = concat_by_station(file_2022_2023, file_2023_2024, station_name)


assert not (df_final["date"].dt.year == 1970).any(), "Quedó alguna fecha mal parseada."
assert df_final.columns.is_unique, "Hay columnas duplicadas."

print(df_final.head())
print(df_final.tail())
print(df_final["date"].min(), "→", df_final["date"].max())
# Out:
#                  date    CO    NO   NO2   NOX   O3   PM10  PM2.5    PRS  \
# 0 2022-01-01 00:00:00  3.04  16.8  30.0  46.8  9.0  182.0  137.0  706.3
# 1 2022-01-01 01:00:00  2.60   8.8  26.4  35.2  9.0  166.0  113.0  705.9
# 2 2022-01-01 02:00:00  2.86  10.8  27.3  38.2  6.0  184.0  141.0  705.7
# 3 2022-01-01 03:00:00  2.98  16.4  28.4  44.8  5.0  201.0  168.0  705.5
# 4 2022-01-01 04:00:00  2.37   9.3  26.5  35.8  5.0  216.0  139.0  705.4
#
#    RAINF    RH  SO2   SR   TOUT    WDR  WDV  WSR
# 0    0.0  63.0  3.7  0.0  22.79   72.0  NaN  1.4
# 1    0.0  66.0  3.3  0.0  21.70  357.0  NaN  3.2
# 2    0.0  71.0  3.3  0.0  20.41  287.0  NaN  4.0
# 3    0.0  72.0  3.4  0.0  19.81  291.0  NaN  4.7
# 4    0.0  73.0  3.1  0.0  19.22  288.0  NaN  5.9
#                      date  CO    NO   NO2   NOX    O3   PM10  PM2.5    PRS  \
# 22625 2024-07-31 19:00:00 NaN  11.3  13.7  24.9  16.0  173.0   10.0  713.9
# 22626 2024-07-31 20:00:00 NaN  12.8  13.9  26.8  13.0  154.0   30.0  714.8
# 22627 2024-07-31 21:00:00 NaN  12.1  11.4  23.5  10.0    NaN   29.0  715.6
# 22628 2024-07-31 22:00:00 NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN
# 22629 2024-07-31 23:00:00 NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN
#
#        RAINF    RH  SO2   SR   TOUT  WDR    WDV   WSR
# 22625    0.0  45.0  3.0  0.0  30.32  NaN  309.0  20.1
# 22626    0.0  53.0  4.1  0.0  29.02  NaN  296.0  15.8
# 22627    0.0  69.0  5.1  0.0  27.25  NaN  289.0  12.9
# 22628    NaN   NaN  NaN  NaN    NaN  NaN    NaN   NaN
# 22629    NaN   NaN  NaN  NaN    NaN  NaN    NaN   NaN
# 2022-01-01 00:00:00 → 2024-07-31 23:00:00
# /Users/marielalvarez/2025/5to_sem/multivariados/Application-of-multivariate-methods-in-data-science/data/concat_helper.py:64: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   out = pd.concat([df22, df23], ignore_index=True)

# %%
rango_completo = pd.date_range(start=df_final['date'].min(),
                               end=df_final['date'].max(),
                               freq='H')

horas_faltantes = rango_completo.difference(df_final['date'])

print("Cantidad de horas faltantes:", len(horas_faltantes))
print("Ejemplos de horas faltantes:\n", horas_faltantes[:10])
# Out:
# Cantidad de horas faltantes: 2
# Ejemplos de horas faltantes:
#  DatetimeIndex(['2023-02-11 19:00:00', '2023-10-31 17:00:00'], dtype='datetime64[ns]', freq=None)
# /var/folders/l9/hx3k3fcs03d6gz71m2n3t1c80000gn/T/ipykernel_13879/1722369520.py:1: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   rango_completo = pd.date_range(start=df_final['date'].min(),

# %%
df_final.to_excel("../data_limpia/noreste2.xlsx", index=False, engine='openpyxl')
